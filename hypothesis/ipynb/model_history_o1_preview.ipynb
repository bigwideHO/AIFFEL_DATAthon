# %% [markdown]
# # **train.csv**
# - DataFrame info
#
# ```plaintext
# RangeIndex: 1216553 entries, 0 to 1216552
# Data columns (total 13 columns):
#
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
# - 0   transaction_id          1216553 non-null  int64
#   - ex 0
#   - 제거. 예측에 크게 영향을 미치지 않는 단순 식별자이므로 제거해도 무방.
# - 1   apartment_id            1216553 non-null  int64
#   - 아파트 아이디 | ex) 7622
#   - 유지. 아파트의 고유 ID로, 아파트마다 가격 차이가 있을 수 있으므로 유지하는 것이 좋을 수 있음.
# - 2   city                    1216553 non-null  object
#   - 도시 | ex) 서울특별시
#   - 유지.
# - 3   dong                    1216553 non-null  object
#   - 동 | ex) 신교동
#   - 제거. 너무 과하게 디테일함.
# - 4   jibun                   1216553 non-null  object
#   - 지번 | ex) 6-13
#   - 제거. 너무 과하게 디테일함.
# - 5   apt                     1216553 non-null  object
#   - 아파트 단지 이름 | ex) 신현(101동)
#   - 유지.
# - 6   addr_kr                 1216553 non-null  object
#   - 주소 | ex) 신교동 6-13 신현(101동)
#   - 제거. addr_kr = city + dong + jibun + apt
# - 7   exclusive_use_area      1216553 non-null  float64
#   - 전용면적 | ex) 84.82
#   - 유지. 아파트의 전용 면적은 부동산 가격에 중요한 변수이므로 유지.
# - 8   year_of_completion      1216553 non-null  int64
#   - 설립일자 | ex) 2002
#   - 유지. 건축 연도는 아파트의 나이를 계산하는 데 사용될 수 있으므로 유지.
# - 9   transaction_year_month  1216553 non-null  int64
#   - 거래년월 | ex) 200801
#   - 제거 후 변경 (transaction_year)
#   - 제거 후 변경 (transaction_month)
# - 10  transaction_date        1216553 non-null  object
#   - 거래날짜 | ex) 21~31
#   - 제거. 유의미한 데이터는 아닌 것 같음.
# - 11  floor                   1216553 non-null  int64
#   - 층 | ex) 2
#   - 유지
# - 12  transaction_real_price  1216553 non-null  int64
#   - 실거래가(train만 존재) | ex) 37500
#   - 유지
# dtypes: float64(1), int64(6), object(6)
# ```

# %% [markdown]
# # 기본 모델 변천기

# %% [markdown]
# ## 2024.10.4 18:00
# - o1 preview의 첫 모델
#   - Validation RMSE: 9994.70
#   - Test RMSE: 9857.20

# %%
# 패키지/라이브러리 로드
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
df = pd.read_csv("../../dataset/train.csv", encoding="utf-8")

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print(df.dtypes)

# 데이터 샘플링
# df_sampled = df.sample(frac=0.01, random_state=2024) # 1% 만 사용해서 빠르게 학습할 때
df_sampled = df.sample(frac=1, random_state=2024)  # 100% 전부 사용

# 데이터 분석하기
print("\n=== df_sampled.info() ===")
df_sampled.info()

print("\n=== df_sampled.head() ===")
print(df_sampled.head())

# 1. transaction_year_month에서 '년', '월' 분리 (먼저 실행)
if "transaction_year_month" in df_sampled.columns:
    df_sampled["transaction_year"] = df_sampled["transaction_year_month"] // 100
    df_sampled["transaction_month"] = df_sampled["transaction_year_month"] % 100

# 2. 필요없는 컬럼 제거 (존재하지 않으면 무시하도록 수정)
df_sampled = df_sampled.drop(
    [
        "transaction_id",
        "dong",
        "jibun",
        "addr_kr",
        "transaction_year_month",
        "transaction_date",
    ],
    axis=1,
    errors="ignore",
)

# 3. 데이터 타입 변환 및 범주형 변수 처리

# 3-1. 'city' 컬럼 처리
# 'city'의 고유값 수 확인
print("\n=== 'city' 컬럼의 고유값 수 ===")
print(df_sampled["city"].nunique())

if df_sampled["city"].nunique() < 10:
    # 고유값이 적으면 원-핫 인코딩
    df_sampled = pd.get_dummies(df_sampled, columns=["city"], drop_first=True)
else:
    # 고유값이 많으면 타깃 인코딩 적용
    city_mean_price = df_sampled.groupby("city")[
        "transaction_real_price"
    ].mean()
    df_sampled["city_encoded"] = df_sampled["city"].map(city_mean_price)
    df_sampled = df_sampled.drop("city", axis=1)

# 3-2. 'apt' 컬럼에 대한 타깃 인코딩 적용
# 아파트별 평균 거래 가격으로 인코딩
apt_mean_price = df_sampled.groupby("apt")["transaction_real_price"].mean()
df_sampled["apt_encoded"] = df_sampled["apt"].map(apt_mean_price)
df_sampled = df_sampled.drop("apt", axis=1)

# 3-3. 'apartment_id' 컬럼 처리
# 'apartment_id'는 범주형 변수로 간주
print("\n=== 'apartment_id' 컬럼의 고유값 수 ===")
print(df_sampled["apartment_id"].nunique())

# 고유값이 많으므로 타깃 인코딩 적용
apartment_id_mean_price = df_sampled.groupby("apartment_id")[
    "transaction_real_price"
].mean()
df_sampled["apartment_id_encoded"] = df_sampled["apartment_id"].map(
    apartment_id_mean_price
)
df_sampled = df_sampled.drop("apartment_id", axis=1)

# 4. 데이터 분리 (Feature와 Target 나누기)
X = df_sampled.drop("transaction_real_price", axis=1)
y = df_sampled["transaction_real_price"]

# 데이터 정보 출력
print("\n=== X.info() ===")
X.info()
print("\n=== X.head() ===")
print(X.head())
print("\n=== y.describe() ===")
print(y.describe())

# 5. 1단계: train + validation(75%), test(25%)로 나누기
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2024
)

# 6. 2단계: train(75%), validation(25%)으로 나누기
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=2024
)

# 7. 피처 스케일링 (StandardScaler 사용)
scaler_X = StandardScaler()

# 수치형 변수 선택 (스케일링 대상)
numeric_features = X_train.columns

# X_train, X_val, X_test 각각에 대해 스케일링 적용
X_train = scaler_X.fit_transform(X_train)
X_val = scaler_X.transform(X_val)
X_test = scaler_X.transform(X_test)

# y 값은 스케일링하지 않음

# 8. 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Validation 세트로 예측 및 RMSE 계산
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"\nValidation RMSE: {val_rmse:.2f}")

# 10. Test 세트로 예측 및 RMSE 계산
y_test_pred = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE: {test_rmse:.2f}")

# 11. 모델 디버깅용 출력

# X_train, X_val 스케일링 후 값 확인
print("\n=== X_train 스케일링 후 값 (첫 5개) ===")
print(X_train[:5])

print("\n=== X_val 스케일링 후 값 (첫 5개) ===")
print(X_val[:5])

# y_val 실제 값 범위 확인
print("\n=== y_val 실제 값 범위 ===")
print(f"Min: {y_val.min()}, Max: {y_val.max()}")

# y_val_pred 예측 값 범위 확인
print("\n=== y_val_pred 예측 값 범위 ===")
print(f"Min: {y_val_pred.min()}, Max: {y_val_pred.max()}")

# 모델 회귀 계수 확인
print("\n=== 모델 회귀 계수 ===")
print(model.coef_)


# 12. 시각화 함수 정의 및 적용
def plot_results(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    sns.lineplot(
        y=y_true.reset_index(drop=True),
        x=range(len(y_true)),
        label="Actual",
        color="red",
    )
    sns.lineplot(
        y=y_pred, x=range(len(y_pred)), label="Predicted", color="green"
    )
    plt.title(title)
    plt.xlabel("Index")
    plt.ylabel("Price")
    plt.legend()
    plt.show()


# 13. 검증 세트 결과 시각화
plot_results(y_val, y_val_pred, "Model Prediction vs Actual (Validation)")
# Out:
# === 데이터 타입 확인 ===
# transaction_id              int64
# apartment_id                int64
# city                       object
# dong                       object
# jibun                      object
# apt                        object
# addr_kr                    object
# exclusive_use_area        float64
# year_of_completion          int64
# transaction_year_month      int64
# transaction_date           object
# floor                       int64
# transaction_real_price      int64
# dtype: object
#
# === df_sampled.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 129.9+ MB
#
# === df_sampled.head() ===
#          transaction_id  apartment_id   city dong  jibun      apt  \
# 1111339         1113668          7844  서울특별시  종암동    130  아이파크종암동
# 17951             17951          8728  서울특별시  이촌동  399-1       우성
# 1127178         1130638          4576  서울특별시  월계동     13       미륭
# 609215           609215           798  서울특별시  문정동   72-3      건영1
# 156930           156930         10124  서울특별시   창동    305  창동주공1단지
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 1111339  종암동 130 아이파크종암동               59.73                2004
# 17951       이촌동 399-1 우성               58.20                1995
# 1127178        월계동 13 미륭               51.48                1986
# 609215      문정동 72-3 건영1               84.81                1996
# 156930    창동 305 창동주공1단지               59.39                1990
#
#          transaction_year_month transaction_date  floor  \
# 1111339                  201707            21~31     14
# 17951                    201404             1~10      9
# 1127178                  201711            11~20      6
# 609215                   201606            11~20      1
# 156930                   201111            11~20      9
#
#          transaction_real_price
# 1111339                   41500
# 17951                     47000
# 1127178                   35000
# 609215                    49700
# 156930                    24700
#
# === 'city' 컬럼의 고유값 수 ===
# 2
#
# === 'apartment_id' 컬럼의 고유값 수 ===
# 12533
#
# === X.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   exclusive_use_area    1216553 non-null  float64
#  1   year_of_completion    1216553 non-null  int64
#  2   floor                 1216553 non-null  int64
#  3   transaction_year      1216553 non-null  int64
#  4   transaction_month     1216553 non-null  int64
#  5   city_서울특별시            1216553 non-null  bool
#  6   apt_encoded           1216553 non-null  float64
#  7   apartment_id_encoded  1216553 non-null  float64
# dtypes: bool(1), float64(3), int64(4)
# memory usage: 75.4 MB
#
# === X.head() ===
#          exclusive_use_area  year_of_completion  floor  transaction_year  \
# 1111339               59.73                2004     14              2017
# 17951                 58.20                1995      9              2014
# 1127178               51.48                1986      6              2017
# 609215                84.81                1996      1              2016
# 156930                59.39                1990      9              2011
#
#          transaction_month  city_서울특별시   apt_encoded  apartment_id_encoded
# 1111339                  7        True  40162.762431          40162.762431
# 17951                    4        True  42289.808538          63268.000000
# 1127178                 11        True  25914.026217          25914.026217
# 609215                   6        True  31221.370242          54523.888889
# 156930                  11        True  20771.534335          20771.534335
#
# === y.describe() ===
# count    1.216553e+06
# mean     3.822769e+04
# std      3.104898e+04
# min      1.000000e+02
# 25%      1.900000e+04
# 50%      3.090000e+04
# 75%      4.700000e+04
# max      8.200000e+05
# Name: transaction_real_price, dtype: float64
#
# Validation RMSE: 9994.70
# Test RMSE: 9857.20
#
# === X_train 스케일링 후 값 (첫 5개) ===
# [[ 1.80315313 -1.15143257 -0.95919946 -1.34989102  0.50824632  0.79946752
#    2.80720267  2.85819359]
#  [-0.69136644  1.53360392 -1.11038648 -0.31692699  0.81152436  0.79946752
#   -0.42936484 -0.40835489]
#  [-0.62616526  0.63859175  0.25029669  0.71603704 -0.70486583 -1.25083255
#   -0.54432179 -0.51763727]
#  [-0.67113041 -1.26330909 -1.11038648  0.71603704 -1.31142191  0.79946752
#   -0.50015375 -0.47564948]
#  [-0.63717504 -0.92767953  0.55267073  1.40467973  1.41808044  0.79946752
#   -0.19187331 -0.38958033]]
#
# === X_val 스케일링 후 값 (첫 5개) ===
# [[ 0.78725978  1.30985087  1.9133539  -0.31692699  1.72135848 -1.25083255
#    0.18870584 -0.26173294]
#  [-0.64026189  0.30296219  1.45979284 -1.69421236 -0.40158779  0.79946752
#    0.23893803 -0.0479282 ]
#  [-0.80832384 -1.15143257  0.70385775 -0.31692699 -1.31142191  0.79946752
#   -0.57285345 -0.54476053]
#  [-1.54265169 -0.70392649 -1.11038648  0.71603704 -0.70486583  0.79946752
#    0.28171083  0.26762025]
#  [ 0.23331729 -0.25642041 -1.2615735   0.71603704  1.72135848  0.79946752
#   -0.74682155 -0.53292103]]
#
# === y_val 실제 값 범위 ===
# Min: 500, Max: 780000
#
# === y_val_pred 예측 값 범위 ===
# Min: -12413.466534325373, Max: 500145.14892382984
#
# === 모델 회귀 계수 ===
# [ 6332.56232415 -1278.31453408   845.1983303   2932.59595222
#    463.79801734  1627.79730445  -276.34873829 25094.9012123 ]

# %% [markdown]
# ## 2024.10.7 11:11
# - o1 preview의 두 번째 모델 (성능 개선 시도, 실패)
#   - Validation RMSE: 21158.14
#   - Test RMSE: 20781.80- Validation RMSE: 21158.14
# - 결과적으로, 성능은 악화됨.

# %%
# 패키지/라이브러리 로드
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
df = pd.read_csv("../../dataset/train.csv", encoding="utf-8")

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print(df.dtypes)

# 데이터 샘플링 (전체 데이터 사용)
df_sampled = df.copy()  # 전체 데이터를 사용합니다.

# 데이터 분석하기
print("\n=== df_sampled.info() ===")
df_sampled.info()

print("\n=== df_sampled.head() ===")
print(df_sampled.head())

# 1. transaction_year_month에서 '년', '월' 분리
if "transaction_year_month" in df_sampled.columns:
    df_sampled["transaction_year"] = df_sampled["transaction_year_month"] // 100
    df_sampled["transaction_month"] = df_sampled["transaction_year_month"] % 100

# 2. 필요없는 컬럼 제거
df_sampled = df_sampled.drop(
    [
        "transaction_id",         # 제거 (단순 식별자)
        "dong",                   # 제거 (너무 세부적인 위치 정보)
        "jibun",                  # 제거 (너무 세부적인 위치 정보)
        "addr_kr",                # 제거 (중복 정보)
        "transaction_year_month", # 이미 연도와 월로 분리함
        "transaction_date"        # 제거 (유의미하지 않음)
    ],
    axis=1,
    errors="ignore",
)

# 3. 데이터 타입 변환 및 범주형 변수 처리

# 3-1. 'city' 컬럼 처리
# 'city'의 고유값 수 확인
print("\n=== 'city' 컬럼의 고유값 수 ===")
print(df_sampled['city'].nunique())

# 'city' 컬럼의 고유값이 적으므로 원-핫 인코딩 적용
df_sampled = pd.get_dummies(df_sampled, columns=['city'], drop_first=True)

# 3-2. 'apt' 컬럼 처리
# 'apt' 컬럼은 고유값이 많으므로, 원-핫 인코딩을 적용하면 차원이 커집니다.
# 따라서, 'apt' 컬럼에 빈도 인코딩을 적용합니다.

# 'apt' 컬럼의 고유값 수 확인
print("\n=== 'apt' 컬럼의 고유값 수 ===")
print(df_sampled['apt'].nunique())

# 3-2-1. 'apt' 컬럼에 빈도 인코딩 적용
apt_counts = df_sampled['apt'].value_counts()
df_sampled['apt_freq'] = df_sampled['apt'].map(apt_counts)

# 3-2-2. 'apt' 컬럼 제거
df_sampled = df_sampled.drop('apt', axis=1)

# 3-3. 'apartment_id' 컬럼 처리
# 'apartment_id'는 아파트의 고유 ID로, 숫자형이지만 범주형 변수로 볼 수 있습니다.
# 고유값이 많으므로 빈도 인코딩을 적용합니다.

# 'apartment_id' 컬럼의 고유값 수 확인
print("\n=== 'apartment_id' 컬럼의 고유값 수 ===")
print(df_sampled['apartment_id'].nunique())

# 3-3-1. 'apartment_id'에 빈도 인코딩 적용
apartment_id_counts = df_sampled['apartment_id'].value_counts()
df_sampled['apartment_id_freq'] = df_sampled['apartment_id'].map(apartment_id_counts)

# 3-3-2. 'apartment_id' 컬럼 제거
df_sampled = df_sampled.drop('apartment_id', axis=1)

# 4. 데이터 분리 (Feature와 Target 나누기)
X = df_sampled.drop("transaction_real_price", axis=1)
y = df_sampled["transaction_real_price"]

# 데이터 정보 출력
print("\n=== X.info() ===")
X.info()
print("\n=== X.head() ===")
print(X.head())
print("\n=== y.describe() ===")
print(y.describe())

# 5. 데이터 분할: train + validation(75%), test(25%)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2024
)

# 6. 데이터 분할: train(75%), validation(25%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=2024
)

# 7. 피처 스케일링 (StandardScaler 사용)
scaler = StandardScaler()

# 수치형 변수 선택 (스케일링 대상)
numeric_features = X_train.select_dtypes(include=[np.number]).columns
print("\n=== 스케일링 대상 수치형 피처 ===")
print(numeric_features)

# X_train, X_val, X_test 각각에 대해 스케일링 적용
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_val[numeric_features] = scaler.transform(X_val[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# y 값은 스케일링하지 않음

# 8. 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Validation 세트로 예측 및 RMSE 계산
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"\nValidation RMSE: {val_rmse:.2f}")

# 10. Test 세트로 예측 및 RMSE 계산
y_test_pred = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE: {test_rmse:.2f}")

# 11. 모델 디버깅용 출력

# X_train, X_val 스케일링 후 값 확인
print("\n=== X_train 스케일링 후 값 (첫 5개) ===")
print(X_train.head())

print("\n=== X_val 스케일링 후 값 (첫 5개) ===")
print(X_val.head())

# y_val 실제 값 범위 확인
print("\n=== y_val 실제 값 범위 ===")
print(f"Min: {y_val.min()}, Max: {y_val.max()}")

# y_val_pred 예측 값 범위 확인
print("\n=== y_val_pred 예측 값 범위 ===")
print(f"Min: {y_val_pred.min()}, Max: {y_val_pred.max()}")

# 모델 회귀 계수 확인
print("\n=== 모델 회귀 계수 ===")
print(pd.Series(model.coef_, index=X_train.columns))

# 12. 시각화 함수 정의 및 적용
def plot_results(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=pd.DataFrame({'Actual': y_true.reset_index(drop=True), 'Predicted': y_pred}))
    plt.title(title)
    plt.xlabel('Index')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# 13. 검증 세트 결과 시각화
plot_results(y_val, y_val_pred, "Model Prediction vs Actual (Validation)")
# Out:
# === 데이터 타입 확인 ===
# transaction_id              int64
# apartment_id                int64
# city                       object
# dong                       object
# jibun                      object
# apt                        object
# addr_kr                    object
# exclusive_use_area        float64
# year_of_completion          int64
# transaction_year_month      int64
# transaction_date           object
# floor                       int64
# transaction_real_price      int64
# dtype: object
#
# === df_sampled.info() ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216553 entries, 0 to 1216552
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 120.7+ MB
#
# === df_sampled.head() ===
#    transaction_id  apartment_id   city dong   jibun       apt  \
# 0               0          7622  서울특별시  신교동    6-13  신현(101동)
# 1               1          5399  서울특별시  필운동     142    사직파크맨션
# 2               2          3578  서울특별시  필운동   174-1    두레엘리시안
# 3               3         10957  서울특별시  내수동      95     파크팰리스
# 4               4         10639  서울특별시  내수동  110-15      킹스매너
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
# 2   필운동 174-1 두레엘리시안               84.74                2007
# 3       내수동 95 파크팰리스              146.39                2003
# 4    내수동 110-15 킹스매너              194.43                2004
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000
# 2                  200801             1~10      6                   38500
# 3                  200801            11~20     15                  118000
# 4                  200801            21~31      3                  120000
#
# === 'city' 컬럼의 고유값 수 ===
# 2
#
# === 'apt' 컬럼의 고유값 수 ===
# 10440
#
# === 'apartment_id' 컬럼의 고유값 수 ===
# 12533
#
# === X.info() ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216553 entries, 0 to 1216552
# Data columns (total 8 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   exclusive_use_area  1216553 non-null  float64
#  1   year_of_completion  1216553 non-null  int64
#  2   floor               1216553 non-null  int64
#  3   transaction_year    1216553 non-null  int64
#  4   transaction_month   1216553 non-null  int64
#  5   city_서울특별시          1216553 non-null  bool
#  6   apt_freq            1216553 non-null  int64
#  7   apartment_id_freq   1216553 non-null  int64
# dtypes: bool(1), float64(1), int64(6)
# memory usage: 66.1 MB
#
# === X.head() ===
#    exclusive_use_area  year_of_completion  floor  transaction_year  \
# 0               84.82                2002      2              2008
# 1               99.17                1973      6              2008
# 2               84.74                2007      6              2008
# 3              146.39                2003     15              2008
# 4              194.43                2004      3              2008
#
#    transaction_month  city_서울특별시  apt_freq  apartment_id_freq
# 0                  1        True         5                  5
# 1                  1        True         1                  1
# 2                  1        True        13                 13
# 3                  1        True        55                 55
# 4                  1        True        15                 15
#
# === y.describe() ===
# count    1.216553e+06
# mean     3.822769e+04
# std      3.104898e+04
# min      1.000000e+02
# 25%      1.900000e+04
# 50%      3.090000e+04
# 75%      4.700000e+04
# max      8.200000e+05
# Name: transaction_real_price, dtype: float64
#
# === 스케일링 대상 수치형 피처 ===
# Index(['exclusive_use_area', 'year_of_completion', 'floor', 'transaction_year',
#        'transaction_month', 'apt_freq', 'apartment_id_freq'],
#       dtype='object')
#
# Validation RMSE: 21158.14
# Test RMSE: 20781.80
#
# === X_train 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 423089           -0.638750           -0.927810 -0.960558         -1.349081
# 513712            0.945321            0.414253 -0.354781          0.371552
# 973968           -0.715997           -0.927810  0.856774         -0.660828
# 968180            0.227191            0.749768  0.099552         -1.349081
# 566785            0.232935            1.197122  1.159663          1.059805
#
#         transaction_month  city_서울특별시  apt_freq  apartment_id_freq
# 423089          -0.098463        True  1.797734          -0.463567
# 513712           1.114789        True -0.600948          -0.981389
# 973968           1.114789       False -0.244555           0.242231
# 968180           1.418102       False -0.573057          -0.885627
# 566785           0.811476        True -0.494547          -0.617849
#
# === X_val 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 906972            0.232248           -0.368617  0.099552          0.715678
# 751081            0.229890            0.861607  3.431327          0.371552
# 378055           -1.287622           -0.256779 -0.809114         -1.693207
# 386005            0.210619            1.308961  0.099552         -0.660828
# 20118            -0.624331            0.190575 -0.051892          0.715678
#
#         transaction_month  city_서울특별시  apt_freq  apartment_id_freq
# 906972           1.114789       False  0.331356          -0.014906
# 751081           1.721415       False  0.000272           0.589810
# 378055          -0.098463        True -0.602498          -0.986709
# 386005           0.811476        True -0.556012          -0.827106
# 20118           -0.098463        True -0.424301          -0.374899
#
# === y_val 실제 값 범위 ===
# Min: 730, Max: 790000
#
# === y_val_pred 예측 값 범위 ===
# Min: -28201.939453581566, Max: 169579.73447753047
#
# === 모델 회귀 계수 ===
# exclusive_use_area    17488.410873
# year_of_completion    -1968.704447
# floor                  2545.026141
# transaction_year       3794.332624
# transaction_month       609.247960
# city_서울특별시            28700.452349
# apt_freq              -2051.864021
# apartment_id_freq      3132.668401
# dtype: float64

# %% [markdown]
# ## 2024.10.7 11:23
# ### o1 preview의 두 번째 모델에서 첫 번째 모델로 롤백
# - o1 preview의 첫 모델
#   - Validation RMSE: 9994.70
#   - Test RMSE: 9857.20
# - o1 preview의 두 번째 모델 (성능 개선 시도, 실패)
#   - Validation RMSE: 21158.14
#   - Test RMSE: 20781.80
#   - 차례차례 'o1 preview의 첫 모델' 코드로 갈아끼워서 성능 돌려보기
#     - 3-2 apt 컬럼: 빈도 인코딩 -> 타깃 인코딩으로 롤백
#       - Validation RMSE: 12717.88
#       - Test RMSE: 12427.76
#     - df.copy() -> df.sample(frac=1, random_state=2024)
#       - Validation RMSE: 12444.14
#       - Test RMSE: 12403.52
#     - 7 피처 스케일링 이후의 모든 코드를 전부 바꿔봐도 위와 동일한 결과.
#     - 3-3 apartment_id 컬럼 빈도 인코딩 -> 타깃 인코딩으로 롤백
#       - Validation RMSE: 9994.70
#       - Test RMSE: 9857.20
#     - 결론: 타깃에서 빈도 인코딩으로 바꾼 것이 성능 악화를 가져왔었음.
#       - (GPT-4o) 빈도 인코딩은 차원을 줄이고 계산 속도를 높일 수 있으나, 가격 예측 문제에서는 타깃 인코딩이 더 적합한 인코딩 방식입니다. 타깃 인코딩은 카테고리별 실질적인 의미를 모델에 전달하여 더 정확한 예측 결과를 도출합니다.

# %%
# 패키지/라이브러리 로드
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
df = pd.read_csv("../../dataset/train.csv", encoding="utf-8")

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print(df.dtypes)

# 데이터 샘플링 (전체 데이터 사용)
# df_sampled = df.copy()  # 전체 데이터를 사용합니다.
# df_sampled = df.sample(frac=0.01, random_state=2024) # 1% 만 사용해서 빠르게 학습
df_sampled = df.sample(frac=1, random_state=2024)  # 100% 전부 사용

# 데이터 분석하기
print("\n=== df_sampled.info() ===")
df_sampled.info()

print("\n=== df_sampled.head() ===")
print(df_sampled.head())

# 1. transaction_year_month에서 '년', '월' 분리
if "transaction_year_month" in df_sampled.columns:
    df_sampled["transaction_year"] = df_sampled["transaction_year_month"] // 100
    df_sampled["transaction_month"] = df_sampled["transaction_year_month"] % 100

# 2. 필요없는 컬럼 제거
df_sampled = df_sampled.drop(
    [
        "transaction_id",  # 제거 (단순 식별자)
        "dong",  # 제거 (너무 세부적인 위치 정보)
        "jibun",  # 제거 (너무 세부적인 위치 정보)
        "addr_kr",  # 제거 (중복 정보)
        "transaction_year_month",  # 이미 연도와 월로 분리함
        "transaction_date",  # 제거 (유의미하지 않음)
    ],
    axis=1,
    errors="ignore",
)

# 3. 데이터 타입 변환 및 범주형 변수 처리

# 3-1. 'city' 컬럼 처리
# 'city'의 고유값 수 확인
print("\n=== 'city' 컬럼의 고유값 수 ===")
print(df_sampled["city"].nunique())

# 'city' 컬럼의 고유값이 적으므로 원-핫 인코딩 적용
df_sampled = pd.get_dummies(df_sampled, columns=["city"], drop_first=True)


# 3-2. 'apt' 컬럼 처리
# 'apt' 컬럼은 고유값이 많으므로, 원-핫 인코딩을 적용하면 차원이 커집니다.
# 따라서, 'apt' 컬럼에 타깃 인코딩을 적용합니다.

# 'apt' 컬럼의 고유값 수 확인
print("\n=== 'apt' 컬럼의 고유값 수 ===")
print(df_sampled["apt"].nunique())

# 'apt' 컬럼에 대한 타깃 인코딩 적용

# 아파트별 평균 거래 가격으로 인코딩
apt_mean_price = df_sampled.groupby("apt")["transaction_real_price"].mean()
df_sampled["apt_encoded"] = df_sampled["apt"].map(apt_mean_price)
df_sampled = df_sampled.drop("apt", axis=1)

# 3-3. 'apartment_id' 컬럼 처리
# 'apartment_id'는 범주형 변수로 간주
print("\n=== 'apartment_id' 컬럼의 고유값 수 ===")
print(df_sampled["apartment_id"].nunique())

# 고유값이 많으므로 타깃 인코딩 적용
apartment_id_mean_price = df_sampled.groupby("apartment_id")[
    "transaction_real_price"
].mean()
df_sampled["apartment_id_encoded"] = df_sampled["apartment_id"].map(
    apartment_id_mean_price
)
df_sampled = df_sampled.drop("apartment_id", axis=1)

# 4. 데이터 분리 (Feature와 Target 나누기)
X = df_sampled.drop("transaction_real_price", axis=1)
y = df_sampled["transaction_real_price"]

# 데이터 정보 출력
print("\n=== X.info() ===")
X.info()
print("\n=== X.head() ===")
print(X.head())
print("\n=== y.describe() ===")
print(y.describe())

# 5. 데이터 분할: train + validation(75%), test(25%)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2024
)

# 6. 데이터 분할: train(75%), validation(25%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=2024
)


# 7. 피처 스케일링 (StandardScaler 사용)
scaler = StandardScaler()

# 수치형 변수 선택 (스케일링 대상)
numeric_features = X_train.select_dtypes(include=[np.number]).columns
print("\n=== 스케일링 대상 수치형 피처 ===")
print(numeric_features)

# X_train, X_val, X_test 각각에 대해 스케일링 적용
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_val[numeric_features] = scaler.transform(X_val[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# y 값은 스케일링하지 않음

# 8. 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Validation 세트로 예측 및 RMSE 계산
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"\nValidation RMSE: {val_rmse:.2f}")

# 10. Test 세트로 예측 및 RMSE 계산
y_test_pred = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE: {test_rmse:.2f}")

# 11. 모델 디버깅용 출력

# X_train, X_val 스케일링 후 값 확인
print("\n=== X_train 스케일링 후 값 (첫 5개) ===")
print(X_train.head())

print("\n=== X_val 스케일링 후 값 (첫 5개) ===")
print(X_val.head())

# y_val 실제 값 범위 확인
print("\n=== y_val 실제 값 범위 ===")
print(f"Min: {y_val.min()}, Max: {y_val.max()}")

# y_val_pred 예측 값 범위 확인
print("\n=== y_val_pred 예측 값 범위 ===")
print(f"Min: {y_val_pred.min()}, Max: {y_val_pred.max()}")

# 모델 회귀 계수 확인
print("\n=== 모델 회귀 계수 ===")
print(pd.Series(model.coef_, index=X_train.columns))


# 12. 시각화 함수 정의 및 적용
def plot_results(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    sns.lineplot(
        data=pd.DataFrame(
            {"Actual": y_true.reset_index(drop=True), "Predicted": y_pred}
        )
    )
    plt.title(title)
    plt.xlabel("Index")
    plt.ylabel("Price")
    plt.legend()
    plt.show()


# 13. 검증 세트 결과 시각화
plot_results(y_val, y_val_pred, "Model Prediction vs Actual (Validation)")
# Out:
# === 데이터 타입 확인 ===
# transaction_id              int64
# apartment_id                int64
# city                       object
# dong                       object
# jibun                      object
# apt                        object
# addr_kr                    object
# exclusive_use_area        float64
# year_of_completion          int64
# transaction_year_month      int64
# transaction_date           object
# floor                       int64
# transaction_real_price      int64
# dtype: object
#
# === df_sampled.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 129.9+ MB
#
# === df_sampled.head() ===
#          transaction_id  apartment_id   city dong  jibun      apt  \
# 1111339         1113668          7844  서울특별시  종암동    130  아이파크종암동
# 17951             17951          8728  서울특별시  이촌동  399-1       우성
# 1127178         1130638          4576  서울특별시  월계동     13       미륭
# 609215           609215           798  서울특별시  문정동   72-3      건영1
# 156930           156930         10124  서울특별시   창동    305  창동주공1단지
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 1111339  종암동 130 아이파크종암동               59.73                2004
# 17951       이촌동 399-1 우성               58.20                1995
# 1127178        월계동 13 미륭               51.48                1986
# 609215      문정동 72-3 건영1               84.81                1996
# 156930    창동 305 창동주공1단지               59.39                1990
#
#          transaction_year_month transaction_date  floor  \
# 1111339                  201707            21~31     14
# 17951                    201404             1~10      9
# 1127178                  201711            11~20      6
# 609215                   201606            11~20      1
# 156930                   201111            11~20      9
#
#          transaction_real_price
# 1111339                   41500
# 17951                     47000
# 1127178                   35000
# 609215                    49700
# 156930                    24700
#
# === 'city' 컬럼의 고유값 수 ===
# 2
#
# === 'apt' 컬럼의 고유값 수 ===
# 10440
#
# === 'apartment_id' 컬럼의 고유값 수 ===
# 12533
#
# === X.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   exclusive_use_area    1216553 non-null  float64
#  1   year_of_completion    1216553 non-null  int64
#  2   floor                 1216553 non-null  int64
#  3   transaction_year      1216553 non-null  int64
#  4   transaction_month     1216553 non-null  int64
#  5   city_서울특별시            1216553 non-null  bool
#  6   apt_encoded           1216553 non-null  float64
#  7   apartment_id_encoded  1216553 non-null  float64
# dtypes: bool(1), float64(3), int64(4)
# memory usage: 75.4 MB
#
# === X.head() ===
#          exclusive_use_area  year_of_completion  floor  transaction_year  \
# 1111339               59.73                2004     14              2017
# 17951                 58.20                1995      9              2014
# 1127178               51.48                1986      6              2017
# 609215                84.81                1996      1              2016
# 156930                59.39                1990      9              2011
#
#          transaction_month  city_서울특별시   apt_encoded  apartment_id_encoded
# 1111339                  7        True  40162.762431          40162.762431
# 17951                    4        True  42289.808538          63268.000000
# 1127178                 11        True  25914.026217          25914.026217
# 609215                   6        True  31221.370242          54523.888889
# 156930                  11        True  20771.534335          20771.534335
#
# === y.describe() ===
# count    1.216553e+06
# mean     3.822769e+04
# std      3.104898e+04
# min      1.000000e+02
# 25%      1.900000e+04
# 50%      3.090000e+04
# 75%      4.700000e+04
# max      8.200000e+05
# Name: transaction_real_price, dtype: float64
#
# === 스케일링 대상 수치형 피처 ===
# Index(['exclusive_use_area', 'year_of_completion', 'floor', 'transaction_year',
#        'transaction_month', 'apt_encoded', 'apartment_id_encoded'],
#       dtype='object')
#
# Validation RMSE: 9994.70
# Test RMSE: 9857.20
#
# === X_train 스케일링 후 값 (첫 5개) ===
#          exclusive_use_area  year_of_completion     floor  transaction_year  \
# 497677             1.803153           -1.151433 -0.959199         -1.349891
# 249714            -0.691366            1.533604 -1.110386         -0.316927
# 1038727           -0.626165            0.638592  0.250297          0.716037
# 166780            -0.671130           -1.263309 -1.110386          0.716037
# 1154510           -0.637175           -0.927680  0.552671          1.404680
#
#          transaction_month  city_서울특별시  apt_encoded  apartment_id_encoded
# 497677            0.508246        True     2.807203              2.858194
# 249714            0.811524        True    -0.429365             -0.408355
# 1038727          -0.704866       False    -0.544322             -0.517637
# 166780           -1.311422        True    -0.500154             -0.475649
# 1154510           1.418080        True    -0.191873             -0.389580
#
# === X_val 스케일링 후 값 (첫 5개) ===
#          exclusive_use_area  year_of_completion     floor  transaction_year  \
# 1059551            0.787260            1.309851  1.913354         -0.316927
# 377760            -0.640262            0.302962  1.459793         -1.694212
# 199394            -0.808324           -1.151433  0.703858         -0.316927
# 556993            -1.542652           -0.703926 -1.110386          0.716037
# 402573             0.233317           -0.256420 -1.261573          0.716037
#
#          transaction_month  city_서울특별시  apt_encoded  apartment_id_encoded
# 1059551           1.721358       False     0.188706             -0.261733
# 377760           -0.401588        True     0.238938             -0.047928
# 199394           -1.311422        True    -0.572853             -0.544761
# 556993           -0.704866        True     0.281711              0.267620
# 402573            1.721358        True    -0.746822             -0.532921
#
# === y_val 실제 값 범위 ===
# Min: 500, Max: 780000
#
# === y_val_pred 예측 값 범위 ===
# Min: -12413.46653432538, Max: 500145.1489238291
#
# === 모델 회귀 계수 ===
# exclusive_use_area       6332.562324
# year_of_completion      -1278.314534
# floor                     845.198330
# transaction_year         2932.595952
# transaction_month         463.798017
# city_서울특별시               3337.472933
# apt_encoded              -276.348738
# apartment_id_encoded    25094.901212
# dtype: float64

# %% [markdown]
# # 현재 기본 모델 (2024.7.11 12:23)
# - 결측치/이상치 처리
#   - Validation RMSE: 5088.81
#   - Test RMSE: 5091.53
# - 현재까지는 이 모델이 가장 정확.
# - 시간이 부족하므로, 일단 이 모델을 기본 모델로 적용.

# %%
# 패키지/라이브러리 로드
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
df = pd.read_csv("../../dataset/train.csv", encoding="utf-8")

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print(df.dtypes)

# 데이터 샘플링 (전체 데이터 사용)
# df_sampled = df.copy()  # 전체 데이터를 사용합니다.
# df_sampled = df.sample(frac=0.01, random_state=2024) # 1% 만 사용해서 빠르게 학습
df_sampled = df.sample(frac=1, random_state=2024)  # 100% 전부 사용

# 데이터 분석하기
print("\n=== df_sampled.info() ===")
df_sampled.info()

print("\n=== df_sampled.head() ===")
print(df_sampled.head())

# 1. transaction_year_month에서 '년', '월' 분리
if "transaction_year_month" in df_sampled.columns:
    df_sampled["transaction_year"] = df_sampled["transaction_year_month"] // 100
    df_sampled["transaction_month"] = df_sampled["transaction_year_month"] % 100

# 2. 필요없는 컬럼 제거
df_sampled = df_sampled.drop(
    [
        "transaction_id",  # 제거 (단순 식별자)
        "dong",  # 제거 (너무 세부적인 위치 정보)
        "jibun",  # 제거 (너무 세부적인 위치 정보)
        "addr_kr",  # 제거 (중복 정보)
        "transaction_year_month",  # 이미 연도와 월로 분리함
        "transaction_date",  # 제거 (유의미하지 않음)
    ],
    axis=1,
    errors="ignore",
)

# 2-1. 결측치 처리
print("\n=== 결측치 확인 ===")
missing_values = df_sampled.isnull().sum()
print(missing_values)

# 결측치가 포함된 행을 제거하는 경우
df_sampled = df_sampled.dropna()

# 결측치를 평균 또는 중앙값으로 대체하는 경우
# df_sampled.fillna(df_sampled.mean(), inplace=True)

# 2-2. 이상치 처리 (사분위 범위(IQR)를 이용한 방법)

# 수치형 피처만 선택
numeric_columns = df_sampled.select_dtypes(include=[np.number]).columns

# 각 피처별 IQR을 기반으로 이상치 제거
for column in numeric_columns:
    Q1 = df_sampled[column].quantile(0.25)  # 1사분위
    Q3 = df_sampled[column].quantile(0.75)  # 3사분위
    IQR = Q3 - Q1  # IQR 계산
    lower_bound = Q1 - 1.5 * IQR  # 이상치 하한
    upper_bound = Q3 + 1.5 * IQR  # 이상치 상한

    # 이상치가 범위를 벗어난 값들을 제거
    df_sampled = df_sampled[
        (df_sampled[column] >= lower_bound)
        & (df_sampled[column] <= upper_bound)
    ]

print("\n=== 이상치 처리 완료 후 데이터프레임 정보 ===")
df_sampled.info()

# 3. 데이터 타입 변환 및 범주형 변수 처리

# 3-1. 'city' 컬럼 처리
# 'city'의 고유값 수 확인
print("\n=== 'city' 컬럼의 고유값 수 ===")
print(df_sampled["city"].nunique())

# 'city' 컬럼의 고유값이 적으므로 원-핫 인코딩 적용
df_sampled = pd.get_dummies(df_sampled, columns=["city"], drop_first=True)


# 3-2. 'apt' 컬럼 처리
# 'apt' 컬럼은 고유값이 많으므로, 원-핫 인코딩을 적용하면 차원이 커집니다.
# 따라서, 'apt' 컬럼에 타깃 인코딩을 적용합니다.

# 'apt' 컬럼의 고유값 수 확인
print("\n=== 'apt' 컬럼의 고유값 수 ===")
print(df_sampled["apt"].nunique())

# 'apt' 컬럼에 대한 타깃 인코딩 적용
# 아파트별 평균 거래 가격으로 인코딩
apt_mean_price = df_sampled.groupby("apt")["transaction_real_price"].mean()
df_sampled["apt_encoded"] = df_sampled["apt"].map(apt_mean_price)
df_sampled = df_sampled.drop("apt", axis=1)

# 3-3. 'apartment_id' 컬럼 처리
# 'apartment_id'는 범주형 변수로 간주
print("\n=== 'apartment_id' 컬럼의 고유값 수 ===")
print(df_sampled["apartment_id"].nunique())

# 고유값이 많으므로 타깃 인코딩 적용
apartment_id_mean_price = df_sampled.groupby("apartment_id")[
    "transaction_real_price"
].mean()
df_sampled["apartment_id_encoded"] = df_sampled["apartment_id"].map(
    apartment_id_mean_price
)
df_sampled = df_sampled.drop("apartment_id", axis=1)

# 4. 데이터 분리 (Feature와 Target 나누기)
X = df_sampled.drop("transaction_real_price", axis=1)
y = df_sampled["transaction_real_price"]

# 데이터 정보 출력
print("\n=== X.info() ===")
X.info()
print("\n=== X.head() ===")
print(X.head())
print("\n=== y.describe() ===")
print(y.describe())

# 5. 데이터 분할: train + validation(75%), test(25%)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2024
)

# 6. 데이터 분할: train(75%), validation(25%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=2024
)


# 7. 피처 스케일링 (StandardScaler 사용)
scaler = StandardScaler()

# 수치형 변수 선택 (스케일링 대상)
numeric_features = X_train.select_dtypes(include=[np.number]).columns
print("\n=== 스케일링 대상 수치형 피처 ===")
print(numeric_features)

# X_train, X_val, X_test 각각에 대해 스케일링 적용
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_val[numeric_features] = scaler.transform(X_val[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# y 값은 스케일링하지 않음

# 8. 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Validation 세트로 예측 및 RMSE 계산
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"\nValidation RMSE: {val_rmse:.2f}")

# 10. Test 세트로 예측 및 RMSE 계산
y_test_pred = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE: {test_rmse:.2f}")

# 11. 모델 디버깅용 출력

# X_train, X_val 스케일링 후 값 확인
print("\n=== X_train 스케일링 후 값 (첫 5개) ===")
print(X_train.head())

print("\n=== X_val 스케일링 후 값 (첫 5개) ===")
print(X_val.head())

# y_val 실제 값 범위 확인
print("\n=== y_val 실제 값 범위 ===")
print(f"Min: {y_val.min()}, Max: {y_val.max()}")

# y_val_pred 예측 값 범위 확인
print("\n=== y_val_pred 예측 값 범위 ===")
print(f"Min: {y_val_pred.min()}, Max: {y_val_pred.max()}")

# 모델 회귀 계수 확인
print("\n=== 모델 회귀 계수 ===")
print(pd.Series(model.coef_, index=X_train.columns))


# 12. 시각화 함수 정의 및 적용
def plot_results(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    sns.lineplot(
        data=pd.DataFrame(
            {"Actual": y_true.reset_index(drop=True), "Predicted": y_pred}
        )
    )
    plt.title(title)
    plt.xlabel("Index")
    plt.ylabel("Price")
    plt.legend()
    plt.show()


# 13. 검증 세트 결과 시각화
plot_results(y_val, y_val_pred, "Model Prediction vs Actual (Validation)")
# Out:
# === 데이터 타입 확인 ===
# transaction_id              int64
# apartment_id                int64
# city                       object
# dong                       object
# jibun                      object
# apt                        object
# addr_kr                    object
# exclusive_use_area        float64
# year_of_completion          int64
# transaction_year_month      int64
# transaction_date           object
# floor                       int64
# transaction_real_price      int64
# dtype: object
#
# === df_sampled.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 129.9+ MB
#
# === df_sampled.head() ===
#          transaction_id  apartment_id   city dong  jibun      apt  \
# 1111339         1113668          7844  서울특별시  종암동    130  아이파크종암동
# 17951             17951          8728  서울특별시  이촌동  399-1       우성
# 1127178         1130638          4576  서울특별시  월계동     13       미륭
# 609215           609215           798  서울특별시  문정동   72-3      건영1
# 156930           156930         10124  서울특별시   창동    305  창동주공1단지
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 1111339  종암동 130 아이파크종암동               59.73                2004
# 17951       이촌동 399-1 우성               58.20                1995
# 1127178        월계동 13 미륭               51.48                1986
# 609215      문정동 72-3 건영1               84.81                1996
# 156930    창동 305 창동주공1단지               59.39                1990
#
#          transaction_year_month transaction_date  floor  \
# 1111339                  201707            21~31     14
# 17951                    201404             1~10      9
# 1127178                  201711            11~20      6
# 609215                   201606            11~20      1
# 156930                   201111            11~20      9
#
#          transaction_real_price
# 1111339                   41500
# 17951                     47000
# 1127178                   35000
# 609215                    49700
# 156930                    24700
#
# === 결측치 확인 ===
# apartment_id              0
# city                      0
# apt                       0
# exclusive_use_area        0
# year_of_completion        0
# floor                     0
# transaction_real_price    0
# transaction_year          0
# transaction_month         0
# dtype: int64
#
# === 이상치 처리 완료 후 데이터프레임 정보 ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045605 entries, 1111339 to 532104
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   apartment_id            1045605 non-null  int64
#  1   city                    1045605 non-null  object
#  2   apt                     1045605 non-null  object
#  3   exclusive_use_area      1045605 non-null  float64
#  4   year_of_completion      1045605 non-null  int64
#  5   floor                   1045605 non-null  int64
#  6   transaction_real_price  1045605 non-null  int64
#  7   transaction_year        1045605 non-null  int64
#  8   transaction_month       1045605 non-null  int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 79.8+ MB
#
# === 'city' 컬럼의 고유값 수 ===
# 2
#
# === 'apt' 컬럼의 고유값 수 ===
# 9378
#
# === 'apartment_id' 컬럼의 고유값 수 ===
# 11328
#
# === X.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045605 entries, 1111339 to 532104
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   exclusive_use_area    1045605 non-null  float64
#  1   year_of_completion    1045605 non-null  int64
#  2   floor                 1045605 non-null  int64
#  3   transaction_year      1045605 non-null  int64
#  4   transaction_month     1045605 non-null  int64
#  5   city_서울특별시            1045605 non-null  bool
#  6   apt_encoded           1045605 non-null  float64
#  7   apartment_id_encoded  1045605 non-null  float64
# dtypes: bool(1), float64(3), int64(4)
# memory usage: 64.8 MB
#
# === X.head() ===
#          exclusive_use_area  year_of_completion  floor  transaction_year  \
# 1111339               59.73                2004     14              2017
# 17951                 58.20                1995      9              2014
# 1127178               51.48                1986      6              2017
# 609215                84.81                1996      1              2016
# 156930                59.39                1990      9              2011
#
#          transaction_month  city_서울특별시   apt_encoded  apartment_id_encoded
# 1111339                  7        True  40162.762431          40162.762431
# 17951                    4        True  38284.998687          54743.814433
# 1127178                 11        True  25914.026217          25914.026217
# 609215                   6        True  30717.298507          54523.888889
# 156930                  11        True  20771.534335          20771.534335
#
# === y.describe() ===
# count    1.045605e+06
# mean     3.124220e+04
# std      1.711955e+04
# min      3.500000e+02
# 25%      1.790000e+04
# 50%      2.830000e+04
# 75%      4.150000e+04
# max      8.255000e+04
# Name: transaction_real_price, dtype: float64
#
# === 스케일링 대상 수치형 피처 ===
# Index(['exclusive_use_area', 'year_of_completion', 'floor', 'transaction_year',
#        'transaction_month', 'apt_encoded', 'apartment_id_encoded'],
#       dtype='object')
#
# Validation RMSE: 5088.81
# Test RMSE: 5091.53
#
# === X_train 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 905922            0.671341            0.576315  2.245555          0.739364
# 663575            1.367130           -2.425199  1.043036          0.395113
# 824788           -0.611062            1.056558  1.386613          0.050861
# 987418           -1.073232            0.696376  1.901979          1.083616
# 425865            0.651581           -0.864412 -1.190213         -0.981894
#
#         transaction_month  city_서울특별시  apt_encoded  apartment_id_encoded
# 905922           0.820214       False    -0.111285             -0.104859
# 663575           1.427000       False     0.352949             -0.422006
# 824788          -0.696752       False    -0.511822             -0.482378
# 987418           0.820214       False    -1.032130             -0.972786
# 425865           0.213427        True     0.178008              0.413380
#
# === X_val 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 397099           -2.381932            1.656860  1.214825          0.739364
# 176986            0.670824            0.096073  1.730190         -1.670397
# 990697            2.308535            1.296679  0.527671         -0.637642
# 766404           -0.596229            0.816436  2.245555         -1.326145
# 971535           -0.623469            0.576315 -0.331271         -0.981894
#
#         transaction_month  city_서울특별시  apt_encoded  apartment_id_encoded
# 397099          -1.303538        True    -0.951354             -0.896652
# 176986          -1.606931        True     0.382901              0.561226
# 990697          -0.393359       False    -0.234959             -0.221426
# 766404           0.516820       False    -0.754000             -0.710640
# 971535           1.730393       False    -0.801194             -0.755121
#
# === y_val 실제 값 범위 ===
# Min: 350, Max: 82540
#
# === y_val_pred 예측 값 범위 ===
# Min: -8043.378492654487, Max: 84778.81650889544
#
# === 모델 회귀 계수 ===
# exclusive_use_area       3356.227898
# year_of_completion       -863.138701
# floor                     586.712364
# transaction_year         2492.131861
# transaction_month         344.284552
# city_서울특별시               1802.553014
# apt_encoded              -252.747182
# apartment_id_encoded    14327.291531
# dtype: float64

# %% [markdown]
# # 2024.7.11 14:36
# - 'dong'컬럼 추가
#   - Validation RMSE: 5015.39
#   - Test RMSE: 5019.77

# %%
# 패키지/라이브러리 로드
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터 불러오기
df = pd.read_csv("../../dataset/train.csv", encoding="utf-8")

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print(df.dtypes)

# 데이터 샘플링 (전체 데이터 사용)
# df_sampled = df.copy()  # 전체 데이터를 사용합니다.
# df_sampled = df.sample(frac=0.01, random_state=2024) # 1% 만 사용해서 빠르게 학습
df_sampled = df.sample(frac=1, random_state=2024)  # 100% 전부 사용

# 데이터 분석하기
print("\n=== df_sampled.info() ===")
df_sampled.info()

print("\n=== df_sampled.head() ===")
print(df_sampled.head())

# 1. transaction_year_month에서 '년', '월' 분리
if "transaction_year_month" in df_sampled.columns:
    df_sampled["transaction_year"] = df_sampled["transaction_year_month"] // 100
    df_sampled["transaction_month"] = df_sampled["transaction_year_month"] % 100

# 2. 필요없는 컬럼 제거
df_sampled = df_sampled.drop(
    [
        "transaction_id",  # 제거 (단순 식별자)
        "jibun",  # 제거 (너무 세부적인 위치 정보)
        "addr_kr",  # 제거 (중복 정보)
        "transaction_year_month",  # 이미 연도와 월로 분리함
        "transaction_date",  # 제거 (유의미하지 않음)
    ],
    axis=1,
    errors="ignore",
)

# 2-1. 결측치 처리
print("\n=== 결측치 확인 ===")
missing_values = df_sampled.isnull().sum()
print(missing_values)

# 결측치가 포함된 행을 제거하는 경우
df_sampled = df_sampled.dropna()

# 결측치를 평균 또는 중앙값으로 대체하는 경우
# df_sampled.fillna(df_sampled.mean(), inplace=True)


# 2-2. 이상치 처리 (사분위 범위(IQR)를 이용한 방법)

# 수치형 피처만 선택
numeric_columns = df_sampled.select_dtypes(include=[np.number]).columns

# 각 피처별 IQR을 기반으로 이상치 제거
for column in numeric_columns:
    Q1 = df_sampled[column].quantile(0.25)  # 1사분위
    Q3 = df_sampled[column].quantile(0.75)  # 3사분위
    IQR = Q3 - Q1  # IQR 계산
    lower_bound = Q1 - 1.5 * IQR  # 이상치 하한
    upper_bound = Q3 + 1.5 * IQR  # 이상치 상한

    # 이상치가 범위를 벗어난 값들을 제거
    df_sampled = df_sampled[
        (df_sampled[column] >= lower_bound)
        & (df_sampled[column] <= upper_bound)
    ]

print("\n=== 이상치 처리 완료 후 데이터프레임 정보 ===")
df_sampled.info()

# 3. 데이터 타입 변환 및 범주형 변수 처리

# 3-1. 'city' 컬럼 처리 (타깃 인코딩)
print("\n=== 'city' 컬럼의 고유값 수 ===")
print(df_sampled["city"].nunique())

# 'city' 컬럼에 대한 타깃 인코딩 적용
city_mean_price = df_sampled.groupby("city")["transaction_real_price"].mean()
df_sampled["city_encoded"] = df_sampled["city"].map(city_mean_price)
df_sampled = df_sampled.drop("city", axis=1)

# 3-2. 'dong' 컬럼 처리 (타깃 인코딩)
print("\n=== 'dong' 컬럼의 고유값 수 ===")
print(df_sampled["dong"].nunique())

# 'dong' 컬럼에 대한 타깃 인코딩 적용
dong_mean_price = df_sampled.groupby("dong")["transaction_real_price"].mean()
df_sampled["dong_encoded"] = df_sampled["dong"].map(dong_mean_price)
df_sampled = df_sampled.drop("dong", axis=1)

# 3-3. 'apt' 컬럼 처리 (타깃 인코딩)
print("\n=== 'apt' 컬럼의 고유값 수 ===")
print(df_sampled["apt"].nunique())

# 'apt' 컬럼에 대한 타깃 인코딩 적용
apt_mean_price = df_sampled.groupby("apt")["transaction_real_price"].mean()
df_sampled["apt_encoded"] = df_sampled["apt"].map(apt_mean_price)
df_sampled = df_sampled.drop("apt", axis=1)

# 3-4. 'apartment_id' 컬럼 처리 (타깃 인코딩)
print("\n=== 'apartment_id' 컬럼의 고유값 수 ===")
print(df_sampled["apartment_id"].nunique())

# 'apartment_id' 컬럼에 대한 타깃 인코딩 적용
apartment_id_mean_price = df_sampled.groupby("apartment_id")[
    "transaction_real_price"
].mean()
df_sampled["apartment_id_encoded"] = df_sampled["apartment_id"].map(
    apartment_id_mean_price
)
df_sampled = df_sampled.drop("apartment_id", axis=1)
# 4. 데이터 분리 (Feature와 Target 나누기)
X = df_sampled.drop("transaction_real_price", axis=1)
y = df_sampled["transaction_real_price"]

# 데이터 정보 출력
print("\n=== X.info() ===")
X.info()
print("\n=== X.head() ===")
print(X.head())
print("\n=== y.describe() ===")
print(y.describe())

# 5. 데이터 분할: train + validation(75%), test(25%)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2024
)

# 6. 데이터 분할: train(75%), validation(25%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=2024
)


# 7. 피처 스케일링 (StandardScaler 사용)
scaler = StandardScaler()

# 수치형 변수 선택 (스케일링 대상)
numeric_features = X_train.select_dtypes(include=[np.number]).columns
print("\n=== 스케일링 대상 수치형 피처 ===")
print(numeric_features)

# X_train, X_val, X_test 각각에 대해 스케일링 적용
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_val[numeric_features] = scaler.transform(X_val[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# y 값은 스케일링하지 않음

# 8. 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Validation 세트로 예측 및 RMSE 계산
y_val_pred = model.predict(X_val)
val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"\nValidation RMSE: {val_rmse:.2f}")

# 10. Test 세트로 예측 및 RMSE 계산
y_test_pred = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print(f"Test RMSE: {test_rmse:.2f}")

# 11. 모델 디버깅용 출력

# X_train, X_val 스케일링 후 값 확인
print("\n=== X_train 스케일링 후 값 (첫 5개) ===")
print(X_train.head())

print("\n=== X_val 스케일링 후 값 (첫 5개) ===")
print(X_val.head())

# y_val 실제 값 범위 확인
print("\n=== y_val 실제 값 범위 ===")
print(f"Min: {y_val.min()}, Max: {y_val.max()}")

# y_val_pred 예측 값 범위 확인
print("\n=== y_val_pred 예측 값 범위 ===")
print(f"Min: {y_val_pred.min()}, Max: {y_val_pred.max()}")

# 모델 회귀 계수 확인
print("\n=== 모델 회귀 계수 ===")
print(pd.Series(model.coef_, index=X_train.columns))


# 12. 시각화 함수 정의 및 적용
def plot_results(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    sns.lineplot(
        data=pd.DataFrame(
            {"Actual": y_true.reset_index(drop=True), "Predicted": y_pred}
        )
    )
    plt.title(title)
    plt.xlabel("Index")
    plt.ylabel("Price")
    plt.legend()
    plt.show()


# 13. 검증 세트 결과 시각화
plot_results(y_val, y_val_pred, "Model Prediction vs Actual (Validation)")
# Out:
# === 데이터 타입 확인 ===
# transaction_id              int64
# apartment_id                int64
# city                       object
# dong                       object
# jibun                      object
# apt                        object
# addr_kr                    object
# exclusive_use_area        float64
# year_of_completion          int64
# transaction_year_month      int64
# transaction_date           object
# floor                       int64
# transaction_real_price      int64
# dtype: object
#
# === df_sampled.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216553 entries, 1111339 to 532104
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 129.9+ MB
#
# === df_sampled.head() ===
#          transaction_id  apartment_id   city dong  jibun      apt  \
# 1111339         1113668          7844  서울특별시  종암동    130  아이파크종암동
# 17951             17951          8728  서울특별시  이촌동  399-1       우성
# 1127178         1130638          4576  서울특별시  월계동     13       미륭
# 609215           609215           798  서울특별시  문정동   72-3      건영1
# 156930           156930         10124  서울특별시   창동    305  창동주공1단지
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 1111339  종암동 130 아이파크종암동               59.73                2004
# 17951       이촌동 399-1 우성               58.20                1995
# 1127178        월계동 13 미륭               51.48                1986
# 609215      문정동 72-3 건영1               84.81                1996
# 156930    창동 305 창동주공1단지               59.39                1990
#
#          transaction_year_month transaction_date  floor  \
# 1111339                  201707            21~31     14
# 17951                    201404             1~10      9
# 1127178                  201711            11~20      6
# 609215                   201606            11~20      1
# 156930                   201111            11~20      9
#
#          transaction_real_price
# 1111339                   41500
# 17951                     47000
# 1127178                   35000
# 609215                    49700
# 156930                    24700
#
# === 결측치 확인 ===
# apartment_id              0
# city                      0
# dong                      0
# apt                       0
# exclusive_use_area        0
# year_of_completion        0
# floor                     0
# transaction_real_price    0
# transaction_year          0
# transaction_month         0
# dtype: int64
#
# === 이상치 처리 완료 후 데이터프레임 정보 ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045605 entries, 1111339 to 532104
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   apartment_id            1045605 non-null  int64
#  1   city                    1045605 non-null  object
#  2   dong                    1045605 non-null  object
#  3   apt                     1045605 non-null  object
#  4   exclusive_use_area      1045605 non-null  float64
#  5   year_of_completion      1045605 non-null  int64
#  6   floor                   1045605 non-null  int64
#  7   transaction_real_price  1045605 non-null  int64
#  8   transaction_year        1045605 non-null  int64
#  9   transaction_month       1045605 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 87.8+ MB
#
# === 'city' 컬럼의 고유값 수 ===
# 2
#
# === 'dong' 컬럼의 고유값 수 ===
# 449
#
# === 'apt' 컬럼의 고유값 수 ===
# 9378
#
# === 'apartment_id' 컬럼의 고유값 수 ===
# 11328
#
# === X.info() ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045605 entries, 1111339 to 532104
# Data columns (total 9 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   exclusive_use_area    1045605 non-null  float64
#  1   year_of_completion    1045605 non-null  int64
#  2   floor                 1045605 non-null  int64
#  3   transaction_year      1045605 non-null  int64
#  4   transaction_month     1045605 non-null  int64
#  5   city_encoded          1045605 non-null  float64
#  6   dong_encoded          1045605 non-null  float64
#  7   apt_encoded           1045605 non-null  float64
#  8   apartment_id_encoded  1045605 non-null  float64
# dtypes: float64(5), int64(4)
# memory usage: 79.8 MB
#
# === X.head() ===
#          exclusive_use_area  year_of_completion  floor  transaction_year  \
# 1111339               59.73                2004     14              2017
# 17951                 58.20                1995      9              2014
# 1127178               51.48                1986      6              2017
# 609215                84.81                1996      1              2016
# 156930                59.39                1990      9              2011
#
#          transaction_month  city_encoded  dong_encoded   apt_encoded  \
# 1111339                  7  39741.313681  39388.570452  40162.762431
# 17951                    4  39741.313681  62762.864679  38284.998687
# 1127178                 11  39741.313681  27518.647048  25914.026217
# 609215                   6  39741.313681  47070.028749  30717.298507
# 156930                  11  39741.313681  28948.787292  20771.534335
#
#          apartment_id_encoded
# 1111339          40162.762431
# 17951            54743.814433
# 1127178          25914.026217
# 609215           54523.888889
# 156930           20771.534335
#
# === y.describe() ===
# count    1.045605e+06
# mean     3.124220e+04
# std      1.711955e+04
# min      3.500000e+02
# 25%      1.790000e+04
# 50%      2.830000e+04
# 75%      4.150000e+04
# max      8.255000e+04
# Name: transaction_real_price, dtype: float64
#
# === 스케일링 대상 수치형 피처 ===
# Index(['exclusive_use_area', 'year_of_completion', 'floor', 'transaction_year',
#        'transaction_month', 'city_encoded', 'dong_encoded', 'apt_encoded',
#        'apartment_id_encoded'],
#       dtype='object')
#
# Validation RMSE: 5015.39
# Test RMSE: 5019.77
#
# === X_train 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 905922            0.671341            0.576315  2.245555          0.739364
# 663575            1.367130           -2.425199  1.043036          0.395113
# 824788           -0.611062            1.056558  1.386613          0.050861
# 987418           -1.073232            0.696376  1.901979          1.083616
# 425865            0.651581           -0.864412 -1.190213         -0.981894
#
#         transaction_month  city_encoded  dong_encoded  apt_encoded  \
# 905922           0.820214     -1.231306     -0.099952    -0.111285
# 663575           1.427000     -1.231306     -0.673137     0.352949
# 824788          -0.696752     -1.231306     -1.391230    -0.511822
# 987418           0.820214     -1.231306     -0.705194    -1.032130
# 425865           0.213427      0.812146      0.526238     0.178008
#
#         apartment_id_encoded
# 905922             -0.104859
# 663575             -0.422006
# 824788             -0.482378
# 987418             -0.972786
# 425865              0.413380
#
# === X_val 스케일링 후 값 (첫 5개) ===
#         exclusive_use_area  year_of_completion     floor  transaction_year  \
# 397099           -2.381932            1.656860  1.214825          0.739364
# 176986            0.670824            0.096073  1.730190         -1.670397
# 990697            2.308535            1.296679  0.527671         -0.637642
# 766404           -0.596229            0.816436  2.245555         -1.326145
# 971535           -0.623469            0.576315 -0.331271         -0.981894
#
#         transaction_month  city_encoded  dong_encoded  apt_encoded  \
# 397099          -1.303538      0.812146     -0.111035    -0.951354
# 176986          -1.606931      0.812146      0.084881     0.382901
# 990697          -0.393359     -1.231306     -0.183986    -0.234959
# 766404           0.516820     -1.231306     -0.912603    -0.754000
# 971535           1.730393     -1.231306     -0.900605    -0.801194
#
#         apartment_id_encoded
# 397099             -0.896652
# 176986              0.561226
# 990697             -0.221426
# 766404             -0.710640
# 971535             -0.755121
#
# === y_val 실제 값 범위 ===
# Min: 350, Max: 82540
#
# === y_val_pred 예측 값 범위 ===
# Min: -7627.0267199801565, Max: 85790.52820182302
#
# === 모델 회귀 계수 ===
# exclusive_use_area       3584.114300
# year_of_completion       -767.274712
# floor                     642.484460
# transaction_year         2535.583610
# transaction_month         345.961305
# city_encoded              230.859282
# dong_encoded             2049.785513
# apt_encoded              -105.160517
# apartment_id_encoded    12772.979435
# dtype: float64

# %% [markdown]
# ### 모델 회귀 계수와 해석
#
# | 피처명                | 설명                                    | 예시 값 | 회귀 계수    | 해석                                                                                                                                     |
# |-----------------------|-----------------------------------------|---------|--------------|------------------------------------------------------------------------------------------------------------------------------------------|
# | **exclusive_use_area**      | 아파트의 전용면적 (제곱미터)            | 84.82   | 6,332.56     | 전용면적이 1㎡ 증가할 때마다 거래 가격이 약 **6,332.56**만큼 증가합니다. 이는 큰 집일수록 가격이 높아짐을 의미합니다.                          |
# | **year_of_completion**      | 아파트 준공 연도                        | 2002    | -1,278.31    | 준공 연도가 1년 증가할 때마다 거래 가격이 약 **1,278.31**만큼 **감소**합니다. 즉, 더 새로운 아파트일수록 가격이 낮아지는 경향을 보입니다.        |
# | **floor**                   | 아파트의 층수                           | 2       | 845.20       | 층수가 1층 증가할 때마다 거래 가격이 약 **845.20**만큼 증가합니다. 높은 층일수록 가격이 높아짐을 나타냅니다.                                    |
# | **transaction_year**        | 거래 연도                               | 2008    | 2,932.60     | 거래 연도가 1년 증가할 때마다 거래 가격이 약 **2,932.60**만큼 증가합니다. 시간이 지남에 따라 부동산 가격이 상승하는 추세를 반영합니다.            |
# | **transaction_month**       | 거래 월 (1~12월)                        | 1       | 463.80       | 거래 월이 1개월 증가할 때마다 거래 가격이 약 **463.80**만큼 증가합니다. 연도 내에서의 계절적 요인이나 월별 가격 변동을 나타냅니다.                |
# | **city_서울특별시**         | 서울특별시 여부 (서울: 1, 그 외: 0)     | 1       | 3,337.47     | 아파트가 서울에 위치할 경우 거래 가격이 약 **3,337.47**만큼 더 높습니다. 서울의 부동산 가격이 다른 지역보다 높음을 반영합니다.                   |
# | **apt_encoded**             | 아파트 단지의 평균 거래 가격 (타깃 인코딩)| 37,500  | -276.35      | 아파트 단지의 평균 거래 가격이 1만큼 증가할 때마다 거래 가격이 약 **276.35**만큼 **감소**합니다. 이는 예상과 반대이며, 상관관계나 다중공선성을 의심해볼 수 있습니다. |
# | **apartment_id_encoded**    | 아파트 ID의 평균 거래 가격 (타깃 인코딩) | 7,622   | 25,094.90    | 아파트 ID의 평균 거래 가격이 1만큼 증가할 때마다 거래 가격이 약 **25,094.90**만큼 증가합니다. 이는 해당 아파트의 고유 가치가 거래 가격에 큰 영향을 미침을 의미합니다. |

# %% [markdown]
# # 추후 개선 제안
# - **다중공선성 확인:**
#   - **분산 팽창 계수(VIF)**를 사용하여 다중공선성을 확인하고, 높은 VIF 값을 가진 변수를 제거하거나 조정합니다.
#
# - **모델 변경:**
#   - 선형 회귀 모델 대신 **릿지(Ridge)** 또는 **라쏘(Lasso)** 회귀를 사용하여 과적합을 방지하고 모델의 일반화 성능을 향상시킬 수 있습니다.
#
# - **데이터 검증:**
#   - **교차 검증**을 통해 모델의 안정성과 성능을 검증합니다.
#
# - **추가 데이터 수집:**
#   - 더 많은 피처(예: 주변 시설, 교통 접근성 등)를 추가하여 모델의 설명력을 높일 수 있습니다.
#
# - **피처 엔지니어링:**
#   - **변수 변환:** 로그 변환이나 표준화를 통해 변수의 분포를 조정합니다.
#   - **아파트 나이**를 계산하여 사용해보세요.
#     - ```python
#       df_sampled['apartment_age'] = df_sampled['transaction_year'] - df_sampled['year_of_completion']
#       # 보류: 성능 지표는 거의 그대로인데, 모델 회귀 계수가 갑자기 이상해짐.
#       #
#       # === 모델 회귀 계수 ===
#       # exclusive_use_area      6.333739e+03
#       # year_of_completion     -1.004855e+14
#       # floor                   8.451887e+02
#       # transaction_year        3.264965e+13
#       # transaction_month       4.637788e+02
#       # city_서울특별시              3.337436e+03
#       # apt_encoded            -2.763243e+02
#       # apartment_id_encoded    2.509489e+04
#       # apartment_age          -1.027334e+14
#       ```
